# %% [markdown]
# This is Nirs implementation of the TACo algorithm in python, aswell as his enhancement of the algorithm called RankedTACo.
#
# You can run this program and see the comparision in the number of steps completed by the RankedTACo vs normal Taco, aswell as see the gap in optimality.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 5.8 MB/s eta 0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2
# WARNING: You are using pip version 21.2.4; however, version 25.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from collections import Counter
import math

# %%
def TACo(n, m, C, d0, gamma, epsilon, b):
    O = np.zeros((n, m), dtype=float)  # Step 1
    P = np.zeros((n, m), dtype=float)  # Step 2
    selections = []  # Step 3
    is_converged = False  # Step 4
    d = d0  # Step 5
    recorded_states = set()  # Step 6
    steps = 0

    while not is_converged:  # Step 7
        steps += 1
        if steps >= 10000:
            print("TACO failed over 10000 steps")
            return -1, 10000

        current_selections = []
        for i in range(n):  # Step 8
            J = b[i, i] * (O[i] - P[i]) - C[i]  # Steps 9-11
            j_star = np.argmax(J)  # Step 13

            P[i, j_star] += n * d  # Step 15
            O[:, j_star] += d  # Step 16

            current_selections.append(j_star)
            selections.append(j_star)  # Step 17

            current_state = (tuple(map(tuple, O - P)), i)  # Store (O - P) and agent i
            if current_state in recorded_states:  # Step 18
                d *= gamma  # Step 20
                recorded_states.clear()  # Step 21
            else:
                recorded_states.add(current_state)  # Step 29

        if len(set(current_selections)) == 1:
            is_converged = True  # Immediate termination if all agents select the same choice
        elif all(np.max(b[i, i] * (O[i] - P[i]) - C[i]) - np.min(b[i, i] * (O[i] - P[i]) - C[i]) < epsilon for i in range(n)):
            is_converged = True  # Steps 22-26

    print("TACo Number of steps:", steps)
    return Counter(selections).most_common(1)[0][0], steps  # Step 31

# %%
import numpy as np
from collections import Counter

def rankedTACo(n, m, C, d0, gamma, epsilon, b):
    O = np.zeros((n, m), dtype=float)
    P = np.zeros((n, m), dtype=float)
    selections = []
    is_converged = False
    d = d0
    recorded_states = set()
    steps_ranked = 0

    while not is_converged:
        steps_ranked += 1

        if steps_ranked >= 10000:
            print("RankedTACO Failed over 10000 steps")
            return -1, 10000

        current_selections = []
        J_matrix = np.zeros((n, m), dtype=float)  # Initialize J as a matrix

        for i in range(n):
            J = b[i, i] * (O[i] - P[i]) - C[i]
            ranked_choices = np.sort(J)
            j_star = np.argmax(J)
            current_selections.append(j_star)
            J_matrix[i] = J

            for index_choices in J:
                index = int(np.where(J == index_choices)[0])
                ranked_index = int(np.where(ranked_choices == index_choices)[0])
                P[i, index] += n * d * (1 + ranked_index)
                O[:, index] += d * (1 + ranked_index)

            # Cycle detection inside loop
            current_state = (tuple(map(tuple, J_matrix)), i)  # Store J matrix and player index
            if current_state in recorded_states:
                d *= gamma
                recorded_states.clear()
            else:
                recorded_states.add(current_state)

        selections.extend(current_selections)
        #print(current_selections)
        if len(set(current_selections)) == 1:
            is_converged = True

        if all(np.max(J_matrix[i]) - np.min(J_matrix[i]) < epsilon for i in range(n)):
            is_converged = True

    print("Ranked TACo number of steps:", steps_ranked)
    return Counter(selections[-n:]).most_common(1)[0][0], steps_ranked

# %%
#This is a randomized simulation
# AT the end it outputs the opt_gap

n = 8




d0 = 5.0
gamma = 0.9
epsilon = 1
rmse = 0
count = 0
opt_gap = 0

ranked_sum = 0
normal_sum = 0

average_steps_taco = 0
average_setps_ranked = 0

diverged_normal = 0
diverged_ranked = 0
average_opt_gap = 0
for i in range(0, 300):

  m = np.random.randint(10, 20)
  #print("Progress", i, "N", n, "M", m)

  diagonal_values = np.random.rand(n)
  b = np.diag(diagonal_values)
  C = np.random.rand(n,m)*50

  #C = np.array([[10 ,4], [7, 9]])
  #b = np.array([[.8 ,0], [0, 1.2]])

  #print("NORMAL")

  result_n, taco_steps = TACo(n, m, C, d0, gamma, epsilon,b)
  result_r, ranked_steps = rankedTACo(n, m, C, d0, gamma, epsilon,b)

  if result_n != -1 and result_r != -1:


    #print(f"The most common selection is: {result_r}")

    for players in range(0, n):
      ranked_sum += C[players][result_r]
      normal_sum += C[players][result_n]

    rmse += ((result_r-result_n)/max(result_r, result_n))**2
    count+=1



    average_setps_ranked += ranked_steps
    average_steps_taco += taco_steps
  else:
    average_setps_ranked += ranked_steps
    average_steps_taco += taco_steps
    if taco_steps >= 10000:
      diverged_normal += 1
    if ranked_steps >= 10000:
      diverged_ranked += 1



opt_gap = ((ranked_sum/normal_sum) - 1)

print("RMSE", math.sqrt(rmse/count))
print("OPT Gap", opt_gap)
print("Average Steps Ranked TACo", average_setps_ranked/count)
print("Average Steps  TACo", average_steps_taco/count)
print("Number of times ranked diverged:", diverged_ranked)
print("Number of times normal diverged:", diverged_normal)
# Out:
# Progress 0 N 8 M 16
# TACo Number of steps: 14
# Ranked TACo number of steps: 11
# Progress 1 N 8 M 17
# TACo Number of steps: 10
# Ranked TACo number of steps: 3
# Progress 2 N 8 M 16
# TACo Number of steps: 12
# Ranked TACo number of steps: 6
# Progress 3 N 8 M 12
# TACo Number of steps: 5
# Ranked TACo number of steps: 6
# Progress 4 N 8 M 13
# TACo Number of steps: 11
# Ranked TACo number of steps: 10
# Progress 5 N 8 M 17
# TACo Number of steps: 21
# Ranked TACo number of steps: 4
# Progress 6 N 8 M 14
# TACo Number of steps: 7
# Ranked TACo number of steps: 14
# Progress 7 N 8 M 15
# /var/folders/3x/y4c80np166bb8ng4y4yx6zkr0000gn/T/ipykernel_37655/2923448490.py:31: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   index = int(np.where(J == index_choices)[0])
# /var/folders/3x/y4c80np166bb8ng4y4yx6zkr0000gn/T/ipykernel_37655/2923448490.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ranked_index = int(np.where(ranked_choices == index_choices)[0])
# TACO failed over 10000 steps
# Ranked TACo number of steps: 194
# Progress 8 N 8 M 14
# TACo Number of steps: 12
# Ranked TACo number of steps: 4
# Progress 9 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 95
# Progress 10 N 8 M 19
# TACo Number of steps: 17
# Ranked TACo number of steps: 8
# Progress 11 N 8 M 15
# TACo Number of steps: 17
# Ranked TACo number of steps: 7
# Progress 12 N 8 M 14
# TACo Number of steps: 11
# Ranked TACo number of steps: 5
# Progress 13 N 8 M 12
# TACo Number of steps: 19
# Ranked TACo number of steps: 2
# Progress 14 N 8 M 15
# /var/folders/3x/y4c80np166bb8ng4y4yx6zkr0000gn/T/ipykernel_37655/3471338793.py:51: RuntimeWarning: invalid value encountered in scalar divide
#   rmse += ((result_r-result_n)/max(result_r, result_n))**2
# TACO failed over 10000 steps
# Ranked TACo number of steps: 15
# Progress 15 N 8 M 14
# TACo Number of steps: 11
# Ranked TACo number of steps: 4
# Progress 16 N 8 M 16
# TACo Number of steps: 12
# Ranked TACo number of steps: 7
# Progress 17 N 8 M 12
# TACo Number of steps: 9
# Ranked TACo number of steps: 7
# Progress 18 N 8 M 14
# TACo Number of steps: 4
# Ranked TACo number of steps: 5
# Progress 19 N 8 M 12
# TACo Number of steps: 10
# Ranked TACo number of steps: 5
# Progress 20 N 8 M 18
# TACo Number of steps: 121
# Ranked TACo number of steps: 20
# Progress 21 N 8 M 10
# TACo Number of steps: 23
# Ranked TACo number of steps: 5
# Progress 22 N 8 M 14
# TACo Number of steps: 13
# Ranked TACo number of steps: 13
# Progress 23 N 8 M 12
# TACo Number of steps: 12
# Ranked TACo number of steps: 10
# Progress 24 N 8 M 10
# TACO failed over 10000 steps
# Ranked TACo number of steps: 7
# Progress 25 N 8 M 14
# TACo Number of steps: 11
# Ranked TACo number of steps: 9
# Progress 26 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 54
# Progress 27 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 34
# Progress 28 N 8 M 13
# TACo Number of steps: 19
# Ranked TACo number of steps: 9
# Progress 29 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 43
# Progress 30 N 8 M 14
# TACo Number of steps: 9
# Ranked TACo number of steps: 4
# Progress 31 N 8 M 10
# TACO failed over 10000 steps
# Ranked TACo number of steps: 16
# Progress 32 N 8 M 18
# TACo Number of steps: 12
# Ranked TACo number of steps: 96
# Progress 33 N 8 M 17
# TACO failed over 10000 steps
# Ranked TACo number of steps: 13
# Progress 34 N 8 M 18
# TACo Number of steps: 13
# Ranked TACo number of steps: 4
# Progress 35 N 8 M 12
# TACo Number of steps: 22
# Ranked TACo number of steps: 35
# Progress 36 N 8 M 10
# TACO failed over 10000 steps
# Ranked TACo number of steps: 83
# Progress 37 N 8 M 13
# TACo Number of steps: 16
# Ranked TACo number of steps: 15
# Progress 38 N 8 M 19
# TACo Number of steps: 19
# Ranked TACo number of steps: 12
# Progress 39 N 8 M 10
# TACo Number of steps: 12
# Ranked TACo number of steps: 6
# Progress 40 N 8 M 10
# TACo Number of steps: 7
# Ranked TACo number of steps: 4
# Progress 41 N 8 M 17
# TACO failed over 10000 steps
# Ranked TACo number of steps: 58
# Progress 42 N 8 M 16
# TACo Number of steps: 16
# Ranked TACo number of steps: 8
# Progress 43 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 5
# Progress 44 N 8 M 14
# TACo Number of steps: 14
# Ranked TACo number of steps: 13
# Progress 45 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 37
# Progress 46 N 8 M 12
# TACo Number of steps: 7
# Ranked TACo number of steps: 4
# Progress 47 N 8 M 10
# TACo Number of steps: 6
# Ranked TACo number of steps: 8
# Progress 48 N 8 M 11
# TACo Number of steps: 24
# Ranked TACo number of steps: 15
# Progress 49 N 8 M 16
# TACo Number of steps: 16
# Ranked TACo number of steps: 11
# Progress 50 N 8 M 16
# TACo Number of steps: 28
# Ranked TACo number of steps: 6
# Progress 51 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 184
# Progress 52 N 8 M 16
# TACo Number of steps: 22
# Ranked TACo number of steps: 6
# Progress 53 N 8 M 16
# TACo Number of steps: 57
# Ranked TACo number of steps: 9
# Progress 54 N 8 M 17
# TACo Number of steps: 21
# Ranked TACo number of steps: 6
# Progress 55 N 8 M 18
# TACo Number of steps: 31
# Ranked TACo number of steps: 10
# Progress 56 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 73
# Progress 57 N 8 M 14
# TACo Number of steps: 61
# Ranked TACo number of steps: 19
# Progress 58 N 8 M 16
# TACo Number of steps: 18
# Ranked TACo number of steps: 12
# Progress 59 N 8 M 19
# TACo Number of steps: 9
# Ranked TACo number of steps: 13
# Progress 60 N 8 M 15
# TACo Number of steps: 16
# Ranked TACo number of steps: 8
# Progress 61 N 8 M 13
# TACo Number of steps: 5
# Ranked TACo number of steps: 7
# Progress 62 N 8 M 13
# TACo Number of steps: 8
# Ranked TACo number of steps: 9
# Progress 63 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 26
# Progress 64 N 8 M 17
# TACo Number of steps: 9
# Ranked TACo number of steps: 6
# Progress 65 N 8 M 18
# TACo Number of steps: 19
# Ranked TACo number of steps: 6
# Progress 66 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 7
# Progress 67 N 8 M 17
# TACO failed over 10000 steps
# Ranked TACo number of steps: 84
# Progress 68 N 8 M 13
# TACo Number of steps: 20
# RankedTACO Failed over 10000 steps
# Progress 69 N 8 M 14
# TACo Number of steps: 11
# Ranked TACo number of steps: 9
# Progress 70 N 8 M 17
# TACo Number of steps: 17
# Ranked TACo number of steps: 19
# Progress 71 N 8 M 15
# TACo Number of steps: 18
# Ranked TACo number of steps: 7
# Progress 72 N 8 M 17
# TACo Number of steps: 13
# Ranked TACo number of steps: 7
# Progress 73 N 8 M 12
# TACo Number of steps: 30
# Ranked TACo number of steps: 6
# Progress 74 N 8 M 19
# TACo Number of steps: 18
# Ranked TACo number of steps: 17
# Progress 75 N 8 M 16
# TACo Number of steps: 11
# Ranked TACo number of steps: 5
# Progress 76 N 8 M 19
# TACo Number of steps: 12
# Ranked TACo number of steps: 7
# Progress 77 N 8 M 17
# TACo Number of steps: 15
# Ranked TACo number of steps: 4
# Progress 78 N 8 M 11
# TACo Number of steps: 47
# Ranked TACo number of steps: 10
# Progress 79 N 8 M 19
# TACo Number of steps: 10
# Ranked TACo number of steps: 7
# Progress 80 N 8 M 11
# TACo Number of steps: 4
# Ranked TACo number of steps: 8
# Progress 81 N 8 M 12
# TACo Number of steps: 12
# Ranked TACo number of steps: 10
# Progress 82 N 8 M 16
# TACo Number of steps: 10
# Ranked TACo number of steps: 7
# Progress 83 N 8 M 14
# TACo Number of steps: 30
# Ranked TACo number of steps: 8
# Progress 84 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 13
# Progress 85 N 8 M 12
# TACo Number of steps: 12
# Ranked TACo number of steps: 5
# Progress 86 N 8 M 11
# TACo Number of steps: 40
# Ranked TACo number of steps: 13
# Progress 87 N 8 M 13
# TACo Number of steps: 11
# Ranked TACo number of steps: 5
# Progress 88 N 8 M 11
# TACo Number of steps: 10
# Ranked TACo number of steps: 16
# Progress 89 N 8 M 13
# TACo Number of steps: 9
# Ranked TACo number of steps: 4
# Progress 90 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 8
# Progress 91 N 8 M 14
# TACO failed over 10000 steps
# Ranked TACo number of steps: 110
# Progress 92 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 20
# Progress 93 N 8 M 19
# TACo Number of steps: 24
# Ranked TACo number of steps: 7
# Progress 94 N 8 M 16
# TACo Number of steps: 19
# Ranked TACo number of steps: 8
# Progress 95 N 8 M 11
# TACo Number of steps: 4
# Ranked TACo number of steps: 6
# Progress 96 N 8 M 19
# TACo Number of steps: 17
# Ranked TACo number of steps: 9
# Progress 97 N 8 M 16
# TACo Number of steps: 31
# Ranked TACo number of steps: 62
# Progress 98 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 40
# Progress 99 N 8 M 15
# TACo Number of steps: 8
# Ranked TACo number of steps: 8
# Progress 100 N 8 M 19
# TACo Number of steps: 10
# Ranked TACo number of steps: 7
# Progress 101 N 8 M 19
# TACo Number of steps: 8
# Ranked TACo number of steps: 8
# Progress 102 N 8 M 19
# TACo Number of steps: 8
# Ranked TACo number of steps: 7
# Progress 103 N 8 M 11
# TACo Number of steps: 9
# Ranked TACo number of steps: 4
# Progress 104 N 8 M 11
# TACo Number of steps: 50
# Ranked TACo number of steps: 13
# Progress 105 N 8 M 18
# TACo Number of steps: 25
# Ranked TACo number of steps: 9
# Progress 106 N 8 M 11
# TACo Number of steps: 18
# Ranked TACo number of steps: 8
# Progress 107 N 8 M 12
# TACo Number of steps: 9
# Ranked TACo number of steps: 7
# Progress 108 N 8 M 14
# TACo Number of steps: 8
# Ranked TACo number of steps: 1
# Progress 109 N 8 M 18
# TACo Number of steps: 21
# Ranked TACo number of steps: 7
# Progress 110 N 8 M 18
# TACo Number of steps: 24
# Ranked TACo number of steps: 13
# Progress 111 N 8 M 10
# TACo Number of steps: 6
# Ranked TACo number of steps: 15
# Progress 112 N 8 M 15
# TACo Number of steps: 10
# Ranked TACo number of steps: 9
# Progress 113 N 8 M 19
# TACo Number of steps: 6
# Ranked TACo number of steps: 6
# Progress 114 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 13
# Progress 115 N 8 M 10
# TACo Number of steps: 30
# Ranked TACo number of steps: 7
# Progress 116 N 8 M 11
# TACO failed over 10000 steps
# Ranked TACo number of steps: 46
# Progress 117 N 8 M 10
# TACo Number of steps: 16
# Ranked TACo number of steps: 6
# Progress 118 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 50
# Progress 119 N 8 M 14
# TACo Number of steps: 15
# Ranked TACo number of steps: 6
# Progress 120 N 8 M 19
# TACo Number of steps: 8
# Ranked TACo number of steps: 6
# Progress 121 N 8 M 15
# TACo Number of steps: 58
# Ranked TACo number of steps: 46
# Progress 122 N 8 M 18
# TACo Number of steps: 32
# Ranked TACo number of steps: 24
# Progress 123 N 8 M 10
# TACo Number of steps: 44
# Ranked TACo number of steps: 13
# Progress 124 N 8 M 11
# TACo Number of steps: 16
# Ranked TACo number of steps: 6
# Progress 125 N 8 M 13
# TACo Number of steps: 12
# Ranked TACo number of steps: 5
# Progress 126 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 21
# Progress 127 N 8 M 11
# TACo Number of steps: 42
# Ranked TACo number of steps: 5
# Progress 128 N 8 M 12
# TACo Number of steps: 13
# Ranked TACo number of steps: 8
# Progress 129 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 34
# Progress 130 N 8 M 19
# TACo Number of steps: 17
# Ranked TACo number of steps: 20
# Progress 131 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 17
# Progress 132 N 8 M 18
# TACo Number of steps: 38
# Ranked TACo number of steps: 17
# Progress 133 N 8 M 14
# TACo Number of steps: 22
# Ranked TACo number of steps: 11
# Progress 134 N 8 M 11
# TACo Number of steps: 8
# Ranked TACo number of steps: 5
# Progress 135 N 8 M 14
# TACo Number of steps: 11
# Ranked TACo number of steps: 8
# Progress 136 N 8 M 11
# TACo Number of steps: 10
# Ranked TACo number of steps: 6
# Progress 137 N 8 M 12
# TACo Number of steps: 28
# Ranked TACo number of steps: 6
# Progress 138 N 8 M 18
# TACo Number of steps: 9
# Ranked TACo number of steps: 8
# Progress 139 N 8 M 10
# TACo Number of steps: 19
# Ranked TACo number of steps: 4
# Progress 140 N 8 M 13
# TACo Number of steps: 45
# Ranked TACo number of steps: 9
# Progress 141 N 8 M 12
# TACo Number of steps: 22
# Ranked TACo number of steps: 3
# Progress 142 N 8 M 10
# TACO failed over 10000 steps
# Ranked TACo number of steps: 11
# Progress 143 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 6
# Progress 144 N 8 M 16
# TACo Number of steps: 7
# Ranked TACo number of steps: 11
# Progress 145 N 8 M 19
# TACo Number of steps: 8
# Ranked TACo number of steps: 8
# Progress 146 N 8 M 14
# TACo Number of steps: 38
# Ranked TACo number of steps: 11
# Progress 147 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 21
# Progress 148 N 8 M 17
# TACo Number of steps: 13
# Ranked TACo number of steps: 10
# Progress 149 N 8 M 12
# TACo Number of steps: 50
# Ranked TACo number of steps: 9
# Progress 150 N 8 M 17
# TACo Number of steps: 21
# Ranked TACo number of steps: 34
# Progress 151 N 8 M 11
# TACO failed over 10000 steps
# Ranked TACo number of steps: 16
# Progress 152 N 8 M 12
# TACo Number of steps: 8
# Ranked TACo number of steps: 7
# Progress 153 N 8 M 13
# TACo Number of steps: 12
# Ranked TACo number of steps: 8
# Progress 154 N 8 M 13
# TACo Number of steps: 16
# Ranked TACo number of steps: 7
# Progress 155 N 8 M 16
# TACo Number of steps: 11
# Ranked TACo number of steps: 13
# Progress 156 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 44
# Progress 157 N 8 M 16
# TACo Number of steps: 8
# Ranked TACo number of steps: 10
# Progress 158 N 8 M 10
# TACo Number of steps: 20
# Ranked TACo number of steps: 3
# Progress 159 N 8 M 19
# TACo Number of steps: 15
# Ranked TACo number of steps: 19
# Progress 160 N 8 M 14
# TACo Number of steps: 35
# Ranked TACo number of steps: 12
# Progress 161 N 8 M 11
# TACo Number of steps: 5
# Ranked TACo number of steps: 9
# Progress 162 N 8 M 16
# TACo Number of steps: 13
# Ranked TACo number of steps: 8
# Progress 163 N 8 M 11
# TACo Number of steps: 10
# Ranked TACo number of steps: 4
# Progress 164 N 8 M 13
# TACo Number of steps: 9
# Ranked TACo number of steps: 10
# Progress 165 N 8 M 14
# TACO failed over 10000 steps
# Ranked TACo number of steps: 11
# Progress 166 N 8 M 19
# TACo Number of steps: 18
# Ranked TACo number of steps: 19
# Progress 167 N 8 M 14
# TACO failed over 10000 steps
# Ranked TACo number of steps: 36
# Progress 168 N 8 M 18
# TACo Number of steps: 16
# Ranked TACo number of steps: 9
# Progress 169 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 4
# Progress 170 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 119
# Progress 171 N 8 M 15
# TACo Number of steps: 15
# Ranked TACo number of steps: 5
# Progress 172 N 8 M 12
# TACo Number of steps: 24
# Ranked TACo number of steps: 21
# Progress 173 N 8 M 17
# TACO failed over 10000 steps
# Ranked TACo number of steps: 24
# Progress 174 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 36
# Progress 175 N 8 M 12
# TACo Number of steps: 9
# Ranked TACo number of steps: 5
# Progress 176 N 8 M 16
# TACo Number of steps: 41
# Ranked TACo number of steps: 9
# Progress 177 N 8 M 14
# TACo Number of steps: 15
# Ranked TACo number of steps: 5
# Progress 178 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 23
# Progress 179 N 8 M 17
# TACo Number of steps: 32
# Ranked TACo number of steps: 5
# Progress 180 N 8 M 16
# TACo Number of steps: 13
# Ranked TACo number of steps: 6
# Progress 181 N 8 M 11
# TACo Number of steps: 16
# Ranked TACo number of steps: 6
# Progress 182 N 8 M 12
# TACo Number of steps: 21
# Ranked TACo number of steps: 8
# Progress 183 N 8 M 13
# TACo Number of steps: 8
# Ranked TACo number of steps: 7
# Progress 184 N 8 M 10
# TACO failed over 10000 steps
# Ranked TACo number of steps: 15
# Progress 185 N 8 M 17
# TACo Number of steps: 53
# Ranked TACo number of steps: 14
# Progress 186 N 8 M 15
# TACo Number of steps: 6
# Ranked TACo number of steps: 5
# Progress 187 N 8 M 16
# TACo Number of steps: 10
# Ranked TACo number of steps: 8
# Progress 188 N 8 M 14
# TACo Number of steps: 9
# Ranked TACo number of steps: 11
# Progress 189 N 8 M 18
# TACo Number of steps: 16
# Ranked TACo number of steps: 5
# Progress 190 N 8 M 18
# TACo Number of steps: 10
# Ranked TACo number of steps: 12
# Progress 191 N 8 M 17
# TACo Number of steps: 12
# Ranked TACo number of steps: 7
# Progress 192 N 8 M 18
# TACo Number of steps: 35
# Ranked TACo number of steps: 6
# Progress 193 N 8 M 13
# TACo Number of steps: 13
# Ranked TACo number of steps: 4
# Progress 194 N 8 M 18
# TACo Number of steps: 40
# Ranked TACo number of steps: 10
# Progress 195 N 8 M 15
# TACo Number of steps: 9
# Ranked TACo number of steps: 7
# Progress 196 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 99
# Progress 197 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 32
# Progress 198 N 8 M 17
# TACo Number of steps: 89
# Ranked TACo number of steps: 16
# Progress 199 N 8 M 18
# TACo Number of steps: 82
# Ranked TACo number of steps: 10
# Progress 200 N 8 M 10
# TACo Number of steps: 7
# Ranked TACo number of steps: 7
# Progress 201 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 32
# Progress 202 N 8 M 10
# TACo Number of steps: 8
# Ranked TACo number of steps: 60
# Progress 203 N 8 M 17
# TACo Number of steps: 11
# Ranked TACo number of steps: 6
# Progress 204 N 8 M 16
# TACo Number of steps: 8
# Ranked TACo number of steps: 9
# Progress 205 N 8 M 17
# TACo Number of steps: 8
# Ranked TACo number of steps: 12
# Progress 206 N 8 M 19
# TACo Number of steps: 38
# Ranked TACo number of steps: 7
# Progress 207 N 8 M 14
# TACo Number of steps: 17
# Ranked TACo number of steps: 9
# Progress 208 N 8 M 14
# TACo Number of steps: 19
# Ranked TACo number of steps: 93
# Progress 209 N 8 M 15
# TACo Number of steps: 24
# Ranked TACo number of steps: 11
# Progress 210 N 8 M 11
# TACo Number of steps: 7
# Ranked TACo number of steps: 7
# Progress 211 N 8 M 17
# TACo Number of steps: 19
# Ranked TACo number of steps: 6
# Progress 212 N 8 M 17
# TACo Number of steps: 17
# Ranked TACo number of steps: 7
# Progress 213 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 43
# Progress 214 N 8 M 15
# TACo Number of steps: 9
# Ranked TACo number of steps: 9
# Progress 215 N 8 M 16
# TACO failed over 10000 steps
# RankedTACO Failed over 10000 steps
# Progress 216 N 8 M 10
# TACo Number of steps: 16
# Ranked TACo number of steps: 14
# Progress 217 N 8 M 17
# TACo Number of steps: 27
# Ranked TACo number of steps: 7
# Progress 218 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 5
# Progress 219 N 8 M 19
# TACo Number of steps: 22
# Ranked TACo number of steps: 1
# Progress 220 N 8 M 17
# TACo Number of steps: 22
# Ranked TACo number of steps: 12
# Progress 221 N 8 M 15
# TACo Number of steps: 11
# Ranked TACo number of steps: 13
# Progress 222 N 8 M 15
# TACo Number of steps: 24
# Ranked TACo number of steps: 29
# Progress 223 N 8 M 18
# TACo Number of steps: 28
# Ranked TACo number of steps: 53
# Progress 224 N 8 M 12
# TACo Number of steps: 8
# Ranked TACo number of steps: 6
# Progress 225 N 8 M 10
# TACo Number of steps: 17
# Ranked TACo number of steps: 16
# Progress 226 N 8 M 13
# TACo Number of steps: 14
# Ranked TACo number of steps: 8
# Progress 227 N 8 M 10
# TACo Number of steps: 74
# Ranked TACo number of steps: 15
# Progress 228 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 80
# Progress 229 N 8 M 13
# TACo Number of steps: 11
# Ranked TACo number of steps: 8
# Progress 230 N 8 M 19
# TACo Number of steps: 23
# Ranked TACo number of steps: 6
# Progress 231 N 8 M 12
# TACo Number of steps: 8
# Ranked TACo number of steps: 5
# Progress 232 N 8 M 12
# TACo Number of steps: 24
# Ranked TACo number of steps: 5
# Progress 233 N 8 M 15
# TACo Number of steps: 9
# Ranked TACo number of steps: 2
# Progress 234 N 8 M 16
# TACo Number of steps: 16
# Ranked TACo number of steps: 14
# Progress 235 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 114
# Progress 236 N 8 M 16
# TACo Number of steps: 15
# Ranked TACo number of steps: 8
# Progress 237 N 8 M 17
# TACo Number of steps: 22
# Ranked TACo number of steps: 11
# Progress 238 N 8 M 12
# TACo Number of steps: 8
# Ranked TACo number of steps: 5
# Progress 239 N 8 M 15
# TACo Number of steps: 5
# Ranked TACo number of steps: 12
# Progress 240 N 8 M 15
# TACo Number of steps: 8
# Ranked TACo number of steps: 12
# Progress 241 N 8 M 11
# TACo Number of steps: 5
# Ranked TACo number of steps: 5
# Progress 242 N 8 M 13
# TACo Number of steps: 8
# Ranked TACo number of steps: 6
# Progress 243 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 48
# Progress 244 N 8 M 15
# TACo Number of steps: 10
# Ranked TACo number of steps: 9
# Progress 245 N 8 M 13
# TACo Number of steps: 6
# Ranked TACo number of steps: 3
# Progress 246 N 8 M 14
# TACo Number of steps: 8
# Ranked TACo number of steps: 3
# Progress 247 N 8 M 17
# TACo Number of steps: 9
# Ranked TACo number of steps: 8
# Progress 248 N 8 M 17
# TACo Number of steps: 16
# Ranked TACo number of steps: 5
# Progress 249 N 8 M 11
# TACo Number of steps: 7
# Ranked TACo number of steps: 4
# Progress 250 N 8 M 11
# TACo Number of steps: 9
# Ranked TACo number of steps: 5
# Progress 251 N 8 M 13
# TACo Number of steps: 52
# Ranked TACo number of steps: 8
# Progress 252 N 8 M 14
# TACo Number of steps: 77
# Ranked TACo number of steps: 12
# Progress 253 N 8 M 17
# TACo Number of steps: 12
# Ranked TACo number of steps: 44
# Progress 254 N 8 M 13
# TACo Number of steps: 8
# Ranked TACo number of steps: 7
# Progress 255 N 8 M 19
# TACo Number of steps: 17
# Ranked TACo number of steps: 10
# Progress 256 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 25
# Progress 257 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 12
# Progress 258 N 8 M 17
# TACo Number of steps: 30
# Ranked TACo number of steps: 23
# Progress 259 N 8 M 16
# TACo Number of steps: 26
# Ranked TACo number of steps: 8
# Progress 260 N 8 M 14
# TACo Number of steps: 19
# Ranked TACo number of steps: 7
# Progress 261 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 121
# Progress 262 N 8 M 12
# TACo Number of steps: 6
# Ranked TACo number of steps: 4
# Progress 263 N 8 M 17
# TACo Number of steps: 19
# Ranked TACo number of steps: 8
# Progress 264 N 8 M 18
# TACo Number of steps: 9
# Ranked TACo number of steps: 20
# Progress 265 N 8 M 12
# TACo Number of steps: 9
# Ranked TACo number of steps: 9
# Progress 266 N 8 M 16
# TACo Number of steps: 11
# Ranked TACo number of steps: 6
# Progress 267 N 8 M 11
# TACo Number of steps: 24
# Ranked TACo number of steps: 6
# Progress 268 N 8 M 19
# TACo Number of steps: 6
# Ranked TACo number of steps: 10
# Progress 269 N 8 M 15
# TACO failed over 10000 steps
# Ranked TACo number of steps: 137
# Progress 270 N 8 M 17
# TACO failed over 10000 steps
# Ranked TACo number of steps: 1
# Progress 271 N 8 M 16
# TACo Number of steps: 20
# Ranked TACo number of steps: 6
# Progress 272 N 8 M 11
# TACo Number of steps: 4
# Ranked TACo number of steps: 1
# Progress 273 N 8 M 18
# TACo Number of steps: 10
# Ranked TACo number of steps: 7
# Progress 274 N 8 M 19
# TACO failed over 10000 steps
# Ranked TACo number of steps: 7
# Progress 275 N 8 M 10
# TACo Number of steps: 10
# Ranked TACo number of steps: 7
# Progress 276 N 8 M 16
# TACo Number of steps: 19
# Ranked TACo number of steps: 7
# Progress 277 N 8 M 13
# TACo Number of steps: 9
# Ranked TACo number of steps: 5
# Progress 278 N 8 M 15
# TACo Number of steps: 9
# Ranked TACo number of steps: 8
# Progress 279 N 8 M 17
# TACo Number of steps: 8
# Ranked TACo number of steps: 7
# Progress 280 N 8 M 11
# TACo Number of steps: 28
# RankedTACO Failed over 10000 steps
# Progress 281 N 8 M 16
# TACO failed over 10000 steps
# Ranked TACo number of steps: 209
# Progress 282 N 8 M 12
# TACo Number of steps: 12
# Ranked TACo number of steps: 5
# Progress 283 N 8 M 13
# TACO failed over 10000 steps
# Ranked TACo number of steps: 14
# Progress 284 N 8 M 18
# TACo Number of steps: 28
# Ranked TACo number of steps: 30
# Progress 285 N 8 M 11
# TACo Number of steps: 6
# Ranked TACo number of steps: 7
# Progress 286 N 8 M 17
# TACo Number of steps: 25
# Ranked TACo number of steps: 16
# Progress 287 N 8 M 18
# TACo Number of steps: 17
# Ranked TACo number of steps: 12
# Progress 288 N 8 M 14
# TACo Number of steps: 18
# Ranked TACo number of steps: 9
# Progress 289 N 8 M 17
# TACo Number of steps: 12
# Ranked TACo number of steps: 11
# Progress 290 N 8 M 14
# TACo Number of steps: 29
# Ranked TACo number of steps: 4
# Progress 291 N 8 M 12
# TACO failed over 10000 steps
# Ranked TACo number of steps: 77
# Progress 292 N 8 M 13
# TACo Number of steps: 6
# Ranked TACo number of steps: 6
# Progress 293 N 8 M 18
# TACO failed over 10000 steps
# Ranked TACo number of steps: 65
# Progress 294 N 8 M 13
# TACo Number of steps: 13
# Ranked TACo number of steps: 4
# Progress 295 N 8 M 12
# TACo Number of steps: 17
# Ranked TACo number of steps: 1
# Progress 296 N 8 M 10
# TACo Number of steps: 9
# Ranked TACo number of steps: 8
# Progress 297 N 8 M 19
# TACo Number of steps: 28
# Ranked TACo number of steps: 5
# Progress 298 N 8 M 15
# TACo Number of steps: 9
# Ranked TACo number of steps: 8
# Progress 299 N 8 M 13
# TACo Number of steps: 19
# Ranked TACo number of steps: 7
# RMSE nan
# OPT Gap 0.008999837764337215
# Average Steps Ranked TACo 149.19409282700423
# Average Steps  TACo 2592.2827004219407
# Number of times ranked diverged: 3
# Number of times normal diverged: 61

# %%
n = 4
m = 24
d0 = 1
epsilon=1
gamma = .9
diagonal_values = np.random.rand(n)
b = np.diag(diagonal_values)*2
C = np.random.rand(n,m)
#result_r, ranked_steps = rankedTACo(n, m, C, d0, gamma, epsilon,b)
result_n, taco_steps = TACo(n, m, C, d0, gamma, epsilon,b)

print("RESULT", result_n)
